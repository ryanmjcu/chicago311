# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chicago311 = pd.read_csv('D:\Python Projects\Projects\Chicago311\chicago311_Service_Requests.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\rteeh\AppData\Local\Temp\ipykernel_9144\1746535478.py:1: SyntaxWarning: invalid escape sequence '\P'
#   chicago311 = pd.read_csv('D:\Python Projects\Projects\Chicago311\chicago311_Service_Requests.csv')

# %%
chicago311_staging = chicago311.copy()

# %%
chicago311_staging.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960595 entries, 0 to 1960594
# Data columns (total 39 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   SR_NUMBER                 object
#  1   SR_TYPE                   object
#  2   SR_SHORT_CODE             object
#  3   CREATED_DEPARTMENT        object
#  4   OWNER_DEPARTMENT          object
#  5   STATUS                    object
#  6   ORIGIN                    object
#  7   CREATED_DATE              object
#  8   LAST_MODIFIED_DATE        object
#  9   CLOSED_DATE               object
#  10  STREET_ADDRESS            object
#  11  CITY                      object
#  12  STATE                     object
#  13  ZIP_CODE                  float64
#  14  STREET_NUMBER             object
#  15  STREET_DIRECTION          object
#  16  STREET_NAME               object
#  17  STREET_TYPE               object
#  18  DUPLICATE                 bool
#  19  LEGACY_RECORD             bool
#  20  LEGACY_SR_NUMBER          float64
#  21  PARENT_SR_NUMBER          object
#  22  COMMUNITY_AREA            float64
#  23  WARD                      float64
#  24  ELECTRICAL_DISTRICT       float64
#  25  ELECTRICITY_GRID          object
#  26  POLICE_SECTOR             float64
#  27  POLICE_DISTRICT           float64
#  28  POLICE_BEAT               float64
#  29  PRECINCT                  float64
#  30  SANITATION_DIVISION_DAYS  float64
#  31  CREATED_HOUR              int64
#  32  CREATED_DAY_OF_WEEK       int64
#  33  CREATED_MONTH             int64
#  34  X_COORDINATE              float64
#  35  Y_COORDINATE              float64
#  36  LATITUDE                  float64
#  37  LONGITUDE                 float64
#  38  LOCATION                  object
# dtypes: bool(2), float64(14), int64(3), object(20)
# memory usage: 557.2+ MB

# %% [markdown]
# ### Data cleaning

# %%
# Convert "%DATE%" field type to datetime
chicago311_staging['CREATED_DATE'] = pd.to_datetime(chicago311_staging['CREATED_DATE'],format = '%m/%d/%Y %H:%M:%S %p')
chicago311_staging['LAST_MODIFIED_DATE'] = pd.to_datetime(chicago311_staging['LAST_MODIFIED_DATE'],format = '%m/%d/%Y %H:%M:%S %p')
chicago311_staging['CLOSED_DATE'] = pd.to_datetime(chicago311_staging['CLOSED_DATE'],format = '%m/%d/%Y %H:%M:%S %p')
chicago311_staging.head()
# Out:
#        SR_NUMBER                      SR_TYPE SR_SHORT_CODE  \
# 0  SR25-00000002    311 INFORMATION ONLY CALL        311IOC
# 1  SR25-00000003    311 INFORMATION ONLY CALL        311IOC
# 2  SR25-00000004    311 INFORMATION ONLY CALL        311IOC
# 3  SR25-00000005  Pothole in Street Complaint           PHF
# 4  SR25-00000006    311 INFORMATION ONLY CALL        311IOC
#
#   CREATED_DEPARTMENT                     OWNER_DEPARTMENT     STATUS  \
# 0  311 City Services                    311 City Services  Completed
# 1  311 City Services                    311 City Services  Completed
# 2  311 City Services                    311 City Services  Completed
# 3  311 City Services  CDOT - Department of Transportation   Canceled
# 4  311 City Services                    311 City Services  Completed
#
#        ORIGIN        CREATED_DATE  LAST_MODIFIED_DATE         CLOSED_DATE  \
# 0  Phone Call 2025-01-01 12:01:27 2025-01-01 12:31:44 2025-01-01 12:01:28
# 1  Phone Call 2025-01-01 12:01:38 2025-01-01 12:31:44 2025-01-01 12:01:39
# 2  Phone Call 2025-01-01 12:02:21 2025-01-01 12:31:44 2025-01-01 12:02:22
# 3  Phone Call 2025-01-01 12:03:06 2025-01-01 12:04:02 2025-01-01 12:04:02
# 4  Phone Call 2025-01-01 12:04:01 2025-01-01 12:31:44 2025-01-01 12:04:02
#
#    ... PRECINCT SANITATION_DIVISION_DAYS CREATED_HOUR  CREATED_DAY_OF_WEEK  \
# 0  ...     46.0                      NaN            0                    4
# 1  ...     46.0                      NaN            0                    4
# 2  ...     46.0                      NaN            0                    4
# 3  ...     46.0                      NaN            0                    4
# 4  ...     46.0                      NaN            0                    4
#
#   CREATED_MONTH  X_COORDINATE  Y_COORDINATE   LATITUDE  LONGITUDE  \
# 0             1  1.162234e+06  1.896561e+06  41.871834 -87.679845
# 1             1  1.162234e+06  1.896561e+06  41.871834 -87.679845
# 2             1  1.162234e+06  1.896561e+06  41.871834 -87.679845
# 3             1  1.162234e+06  1.896561e+06  41.871834 -87.679845
# 4             1  1.162234e+06  1.896561e+06  41.871834 -87.679845
#
#                                  LOCATION
# 0  (41.87183400094043, -87.6798450000019)
# 1  (41.87183400094043, -87.6798450000019)
# 2  (41.87183400094043, -87.6798450000019)
# 3  (41.87183400094043, -87.6798450000019)
# 4  (41.87183400094043, -87.6798450000019)
#
# [5 rows x 39 columns]

# %%
# Identify missing values
print(chicago311_staging['COMMUNITY_AREA'].isna().value_counts())
print(chicago311_staging['WARD'].isna().value_counts())
# Out:
# COMMUNITY_AREA
# False    1958623
# True        1972
# Name: count, dtype: int64
# WARD
# False    1958676
# True        1919
# Name: count, dtype: int64

# %%
# Drop NaN rows since they make up small portion of data, can't be accurately filled with existing data
chicago311_staging = chicago311_staging.dropna(subset = 'COMMUNITY_AREA')
chicago311_staging = chicago311_staging.dropna(subset = 'WARD')
print(chicago311_staging['COMMUNITY_AREA'].isna().value_counts())
print(chicago311_staging['WARD'].isna().value_counts())
# Out:
# COMMUNITY_AREA
# False    1958513
# Name: count, dtype: int64
# WARD
# False    1958513
# Name: count, dtype: int64

# %%
# Now, convert from necessary floats to int
chicago311_staging['COMMUNITY_AREA'] = chicago311_staging['COMMUNITY_AREA'].astype('int')
chicago311_staging['WARD'] = chicago311_staging['WARD'].astype('int')
